# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.5.2'

# %%
arr = np.array([1,2,3])

# %%
arr
# Out:
# array([1, 2, 3])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
soma = arr + 10
print("Array após somar 10:", soma)
# Out:
# Array após somar 10: [11 12 13]

# %%
mult = arr * 15
print("Array após multiplicar 15:", mult)
# Out:
# Array após multiplicar 15: [15 30 45]
