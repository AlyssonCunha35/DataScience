# %%
import numpy as np

# %%
array = np.array([[10,20,30], [40,50,60], [70,80,90]])

print(array.ndim)
print(array.shape)
array
# Out:
# 2
# (3, 3)
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
# Buscar elemento na linha 01 colna 02
elemento = array[1,2]
elemento
# Out:
# np.int64(60)

# %%
# Pegar dados da 1 linha
linha_0 = array[0]
linha_0
# Out:
# array([10, 20, 30])

# %%
# Acessando a coluna 01
coluna_1 = array[:, 1]
coluna_1
# Out:
# array([20, 50, 80])

# %%
# Fatiando para obter um novo array
# Linha 0 a 1 e coluna 1 a 2
subarray = array[0:2, 1:3]
subarray
# Out:
# array([[20, 30],
#        [50, 60]])

# %%
mascara = array > 50
mascara
# Out:
# array([[False, False, False],
#        [False, False,  True],
#        [ True,  True,  True]])

# %%
elementos_maiores_que_50 = array[mascara]

elementos_maiores_que_50
# Out:
# array([60, 70, 80, 90])

# %%
# Modificando elemento 
array[1,1] = 100

array
# Out:
# array([[ 10,  20,  30],
#        [ 40, 100,  60],
#        [ 70,  80,  90]])
